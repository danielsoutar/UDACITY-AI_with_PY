# %%
# We import pandas into Python
import pandas as pd

# We read in a stock data data file into a data frame and see what it looks like
df = pd.read_csv('./GOOG.csv')

# We display the first 5 rows of the DataFrame
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2004-08-19  49.676899  51.693783  47.669952  49.845802  49.845802  44994500
# 1  2004-08-20  50.178635  54.187561  49.925285  53.805050  53.805050  23005800
# 2  2004-08-23  55.017166  56.373344  54.172661  54.346527  54.346527  18393200
# 3  2004-08-24  55.260582  55.439419  51.450363  52.096165  52.096165  15361800
# 4  2004-08-25  52.140873  53.651051  51.604362  52.657513  52.657513   9257400

# %%
# We load the Google stock data into a DataFrame
google_stock = pd.read_csv('GOOG.csv')

# We load the Apple stock data into a DataFrame
apple_stock = pd.read_csv('AAPL.csv')

# We load the Amazon stock data into a DataFrame
amazon_stock = pd.read_csv('AMZN.csv')

# %%
# We create calendar dates between '2000-01-01' and  '2016-12-31'
dates = pd.date_range('2000-01-01', '2016-12-31')

# We create and empty DataFrame that uses the above dates as indices
all_stocks = pd.DataFrame(index = dates)

# %%
# Change the Adj Close column label to Google
google_stock = google_stock.rename(columns = {'Adj Close': 'GOOG'})

# Change the Adj Close column label to Apple
apple_stock = apple_stock.rename(columns = {'Adj Close': 'AAPL'})

# Change the Adj Close column label to Amazon
amazon_stock = amazon_stock.rename(columns = {'Adj Close': 'AMZN'})

# %%
google_stock.head()
# Out:
#          Date       Open       High        Low      Close       GOOG    Volume
# 0  2004-08-19  49.676899  51.693783  47.669952  49.845802  49.845802  44994500
# 1  2004-08-20  50.178635  54.187561  49.925285  53.805050  53.805050  23005800
# 2  2004-08-23  55.017166  56.373344  54.172661  54.346527  54.346527  18393200
# 3  2004-08-24  55.260582  55.439419  51.450363  52.096165  52.096165  15361800
# 4  2004-08-25  52.140873  53.651051  51.604362  52.657513  52.657513   9257400

# %%
print(all_stocks.join(google_stock))
# Out:
#            Date  Open  High  Low  Close  GOOG  Volume
# 2000-01-01  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-02  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-03  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-04  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-05  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-06  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-07  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-08  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-09  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-10  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-11  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-12  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-13  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-14  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-15  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-16  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# ...

# %%
google_stock.dtypes
# Out:
# Date       object
# Open      float64
# High      float64
# Low       float64
# Close     float64
# GOOG      float64
# Volume      int64
# dtype: object

# %%
all_stocks.dtypes
# Out:
# Series([], dtype: object)

# %%
print(all_stocks.join(google_stock))
# Out:
#            Date  Open  High  Low  Close  GOOG  Volume
# 2000-01-01  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-02  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-03  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-04  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-05  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-06  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-07  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-08  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-09  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-10  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-11  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-12  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-13  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-14  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-15  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-16  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# ...

# %%
google_stock
# Out:
#             Date        Open        High         Low       Close        GOOG  \
# 0     2004-08-19   49.676899   51.693783   47.669952   49.845802   49.845802
# 1     2004-08-20   50.178635   54.187561   49.925285   53.805050   53.805050
# 2     2004-08-23   55.017166   56.373344   54.172661   54.346527   54.346527
# 3     2004-08-24   55.260582   55.439419   51.450363   52.096165   52.096165
# 4     2004-08-25   52.140873   53.651051   51.604362   52.657513   52.657513
# 5     2004-08-26   52.135906   53.626213   51.991844   53.606342   53.606342
# 6     2004-08-27   53.700729   53.959049   52.503513   52.732029   52.732029
# 7     2004-08-30   52.299839   52.404160   50.675404   50.675404   50.675404
# 8     2004-08-31   50.819469   51.519913   50.749920   50.854240   50.854240
# 9     2004-09-01   51.018177   51.152302   49.512966   49.801090   49.801090
# 10    2004-09-02   49.274517   50.854240   49.150326   50.427021   50.427021
# ...

# %%
print(google_stock.loc['2016-12-23':'2016-12-26'])
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, GOOG, Volume]
# Index: []

# %%
print(google_stock.loc['2017-10-02': '2017-10-06'])
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, GOOG, Volume]
# Index: []

# %%
print(all_stocks.join(google_stock))
# Out:
#            Date  Open  High  Low  Close  GOOG  Volume
# 2000-01-01  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-02  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-03  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-04  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-05  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-06  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-07  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-08  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-09  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-10  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-11  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-12  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-13  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-14  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-15  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-16  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# ...

# %%
google_stock.tail(500)
# Out:
#             Date        Open        High         Low       Close        GOOG  \
# 2813  2015-10-21  654.150024  655.869995  641.729980  642.609985  642.609985
# 2814  2015-10-22  646.700012  657.799988  644.010010  651.789978  651.789978
# 2815  2015-10-23  727.500000  730.000000  701.500000  702.000000  702.000000
# 2816  2015-10-26  701.549988  719.150024  701.260010  712.780029  712.780029
# 2817  2015-10-27  707.380005  713.619995  704.549988  708.489990  708.489990
# 2818  2015-10-28  707.330017  712.979980  703.080017  712.950012  712.950012
# 2819  2015-10-29  710.500000  718.260010  710.010010  716.919983  716.919983
# 2820  2015-10-30  715.729980  718.000000  710.049988  710.809998  710.809998
# 2821  2015-11-02  711.059998  721.619995  705.849976  721.109985  721.109985
# 2822  2015-11-03  718.859985  724.650024  714.719971  722.159973  722.159973
# 2823  2015-11-04  722.000000  733.099976  721.900024  728.109985  728.109985
# ...

# %%
all_stocks = all_stocks.join(google_stock, lsuffix='_all_stocks', rsuffix='_google')

# %%
print(all_stocks.merge(google_stock))
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, GOOG, Volume]
# Index: []

# %%
print(all_stocks.join(google_stock))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-a97378e0ea4e> in <module>()
# ----> 1 print(all_stocks.join(google_stock))
#
# D:\Anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    6324         # For SparseDataFrame's benefit
#    6325         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 6326                                  rsuffix=rsuffix, sort=sort)
#    6327
#    6328     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# D:\Anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    6339             return merge(self, other, left_on=on, how=how,
#    6340                          left_index=on is None, right_index=True,
# ...

# %%
apple_stock
# Out:
#             Date        Open        High         Low       Close        AAPL  \
# 0     2000-01-03    3.745536    4.017857    3.631696    3.997768    3.596616
# 1     2000-01-04    3.866071    3.950893    3.613839    3.660714    3.293384
# 2     2000-01-05    3.705357    3.948661    3.678571    3.714286    3.341579
# 3     2000-01-06    3.790179    3.821429    3.392857    3.392857    3.052405
# 4     2000-01-07    3.446429    3.607143    3.410714    3.553571    3.196992
# 5     2000-01-10    3.642857    3.651786    3.383929    3.491071    3.140763
# 6     2000-01-11    3.426339    3.549107    3.232143    3.312500    2.980111
# 7     2000-01-12    3.392857    3.410714    3.089286    3.113839    2.801384
# 8     2000-01-13    3.374439    3.526786    3.303571    3.455357    3.108633
# 9     2000-01-14    3.571429    3.651786    3.549107    3.587054    3.227114
# 10    2000-01-18    3.607143    3.785714    3.587054    3.712054    3.339571
# ...

# %%
print(all_stocks.join(google_stock, rsuffix='_goog'))
# Out:
#            Date  Open  High  Low  Close  GOOG  Volume Date_goog  Open_goog  \
# 2000-01-01  NaN   NaN   NaN  NaN    NaN   NaN     NaN       NaN        NaN
# 2000-01-02  NaN   NaN   NaN  NaN    NaN   NaN     NaN       NaN        NaN
# 2000-01-03  NaN   NaN   NaN  NaN    NaN   NaN     NaN       NaN        NaN
# 2000-01-04  NaN   NaN   NaN  NaN    NaN   NaN     NaN       NaN        NaN
# 2000-01-05  NaN   NaN   NaN  NaN    NaN   NaN     NaN       NaN        NaN
# 2000-01-06  NaN   NaN   NaN  NaN    NaN   NaN     NaN       NaN        NaN
# 2000-01-07  NaN   NaN   NaN  NaN    NaN   NaN     NaN       NaN        NaN
# 2000-01-08  NaN   NaN   NaN  NaN    NaN   NaN     NaN       NaN        NaN
# 2000-01-09  NaN   NaN   NaN  NaN    NaN   NaN     NaN       NaN        NaN
# 2000-01-10  NaN   NaN   NaN  NaN    NaN   NaN     NaN       NaN        NaN
# 2000-01-11  NaN   NaN   NaN  NaN    NaN   NaN     NaN       NaN        NaN
# ...

# %%
test = all_stocks.join(google_stock, rsuffix='_goog', inplace = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-10825b1ffa31> in <module>()
# ----> 1 test = all_stocks.join(google_stock, rsuffix='_goog', inplace = True)
#
# TypeError: join() got an unexpected keyword argument 'inplace'

# %%
print(test.loc['2017-10-02': '2017-10-06'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2017-10-02'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
print(test.asof('20150101'))
# Out:
# Date          NaN
# Open          NaN
# High          NaN
# Low           NaN
# Close         NaN
# GOOG          NaN
# Volume        NaN
# Date_goog     NaN
# Open_goog     NaN
# High_goog     NaN
# Low_goog      NaN
# Close_goog    NaN
# GOOG_goog     NaN
# Volume_goog   NaN
# Name: 2015-01-01 00:00:00, dtype: float64

# %%
print(all_stocks.asof('20170101'))
# Out:
# Date     NaN
# Open     NaN
# High     NaN
# Low      NaN
# Close    NaN
# GOOG     NaN
# Volume   NaN
# Name: 2017-01-01 00:00:00, dtype: float64

# %%
all_stocks.head()
# Out:
#                     Date  Open  High  Low  Close  GOOG  Volume
# 2000-01-01 00:00:00  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-02 00:00:00  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-03 00:00:00  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-04 00:00:00  NaN   NaN   NaN  NaN    NaN   NaN     NaN
# 2000-01-05 00:00:00  NaN   NaN   NaN  NaN    NaN   NaN     NaN
